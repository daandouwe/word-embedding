# %% [markdown]
# # Practical 1: word2vec
# <p>Oxford CS - Deep NLP 2017<br>
# https://www.cs.ox.ac.uk/teaching/courses/2016-2017/dl/</p>
# <p>[Yannis Assael, Brendan Shillingford, Chris Dyer]</p>

# %% [markdown]
# This practical is presented as an IPython Notebook, with the code written for recent versions of **Python 3**. The code in this practical will not work with Python 2 unless you modify it. If you are using your own Python installation, ensure you have a setup identical to that described in the installation shell script (which is intended for use with the department lab machines). We will be unable to support installation on personal machines due to time constraints, so please use the lab machines and the setup script if you are unfamiliar with how to install Anaconda.
#
# To execute a notebook cell, press `shift-enter`. The return value of the last command will be displayed, if it is not `None`.
#
# Potentially useful library documentation, references, and resources:
#
# * IPython notebooks: <https://ipython.org/ipython-doc/3/notebook/notebook.html#introduction>
# * Numpy numerical array library: <https://docs.scipy.org/doc/>
# * Gensim's word2vec: <https://radimrehurek.com/gensim/models/word2vec.html>
# * Bokeh interactive plots: <http://bokeh.pydata.org/en/latest/> (we provide plotting code here, but click the thumbnails for more examples to copy-paste)
# * scikit-learn ML library (aka `sklearn`): <http://scikit-learn.org/stable/documentation.html>
# * nltk NLP toolkit: <http://www.nltk.org/>
# * tutorial for processing xml in python using `lxml`: <http://lxml.de/tutorial.html> (we did this for you below, but in case you need it in the future)

# %%
import numpy as np
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f7951436-15f3-433d-9368-2acbdc51c51d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Part 0: Download the TED dataset

# %%
import urllib.request
import zipfile
import lxml.etree

# %%
# Download the dataset if it's not already there: this may take a minute as it is 75MB
if not os.path.isfile('ted_en-20160408.zip'):
    urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")

# %%
# For now, we're only interested in the subtitle text, so let's extract that from the XML:
with zipfile.ZipFile('ted_en-20160408.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))
input_text = '\n'.join(doc.xpath('//content/text()'))
del doc

# %%
input_text.split('\n')[101]
# Out:
# 'A mother of 11 years -- A mother of an 11-year-old girl wrote me, "Very good for me as a tool to work on her confidence, as this past weekend one of her girlfriends argued with her that she does not belong and should not be allowed to live in Norway. So your work has a very special place in my heart and it\'s very important for me."'

# %% [markdown]
# ### Part 1: Preprocessing
#
# In this part, we attempt to clean up the raw subtitles a bit, so that we get only sentences. The following substring shows examples of what we're trying to get rid of. Since it's hard to define precisely what we want to get rid of, we'll just use some simple heuristics.

# %%
i = input_text.find("Hyowon Gweon: See this?")
input_text[i-20:i+150]
# Out:
# ' baby does.\n(Video) Hyowon Gweon: See this? (Ball squeaks) Did you see that? (Ball squeaks) Cool. See this one? (Ball squeaks) Wow.\nLaura Schulz: Told you. (Laughs)\n(Vide'

# %% [markdown]
# Let's start by removing all parenthesized strings using a regex:

# %%
input_text_noparens = re.sub(r'\([^)]*\)', '', input_text)

# %% [markdown]
# We can verify the same location in the text is now clean as follows. We won't worry about the irregular spaces since we'll later split the text into sentences and tokenize it anyway.

# %%
i = input_text_noparens.find("Hyowon Gweon: See this?")
input_text_noparens[i-20:i+150]
# Out:
# "hat the baby does.\n Hyowon Gweon: See this?  Did you see that?  Cool. See this one?  Wow.\nLaura Schulz: Told you. \n HG: See this one?  Hey Clara, this one's for you. You "

# %% [markdown]
# Now, let's attempt to remove speakers' names that occur at the beginning of a line, by deleting pieces of the form "`<up to 20 characters>:`", as shown in this example. Of course, this is an imperfect heuristic.

# %%
sentences_strings_ted = []
for line in input_text_noparens.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)

# Uncomment if you need to save some RAM: these strings are about 50MB.
# del input_text, input_text_noparens

# Let's view the first few:
sentences_strings_ted[:5]
# Out:
# ["Here are two reasons companies fail: they only do more of the same, or they only do what's new",
#  'To me the real, real solution to quality growth is figuring out the balance between two activities: exploration and exploitation',
#  ' Both are necessary, but it can be too much of a good thing',
#  'Consider Facit',
#  " I'm actually old enough to remember them"]

# %%
line = 'Hyowon Gweon: ' + input_text_noparens.split('\n')[0]
m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)

# ^(...)?(___)$ matches the RE (...) at the start of a string 0 or 1 times, then matches the RE (___) at the end of 
# string precisely 1 time

## (?:(?P<precolon>[^:]{,20}):)
# (?:(...):) matches the RE (...): "Matches whatever regular expression is inside the parentheses, 
# but the substring matched by the group cannot be retrieved after performing a match or referenced 
# later in the pattern.
# (?P<precolon>[^:]{,20}) matches the regular expressions [^:]{,20} gives it label <precolon> and returns this in a dictionary
# [^:] matches all character except :
# {,20} lets the previous RE match 0-20 times

## (?P<postcolon>.*)$ ##
# (?P<postcolon>...) matches the regular expressions ... gives it label <postcolon> and returns this in a dictionary
# . matches any character except a newline
# * matches 0 or more of repetitions of the preceding RE except a newline \n
# hence .* will match 0 or more of anything 
# $ macthes the end of the string

# %% [markdown]
# Now that we have sentences, we're ready to tokenize each of them into words. This tokenization is imperfect, of course. For instance, how many tokens is "can't", and where/how do we split it? We'll take the simplest naive approach of splitting on spaces. Before splitting, we remove non-alphanumeric characters, such as punctuation. You may want to consider the following question: why do we replace these characters with spaces rather than deleting them? Think of a case where this yields a different answer.

# %%
sentences_ted = []
for sent_str in sentences_strings_ted:
    # [^a-z0-9]+ matches all characters except a-z and 0-9 1 or more times
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    sentences_ted.append(tokens)

# %% [markdown]
# Two sample processed sentences:

# %%
len(sentences_ted)
# Out:
# 266694

# %%
print(sentences_ted[0])
print(sentences_ted[1])
# Out:
# ['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new']
# ['to', 'me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is', 'figuring', 'out', 'the', 'balance', 'between', 'two', 'activities', 'exploration', 'and', 'exploitation']

# %% [markdown]
# ### Part 2: Word Frequencies

# %% [markdown]
# If you store the counts of the top 1000 words in a list called `counts_ted_top1000`, the code below will plot the histogram requested in the writeup.

# %%
from collections import Counter

counts_ted_top1000 = [b for a,b in Counter((item for sublist in sentences_ted for item in sublist)).most_common(1000)]

# %% [markdown]
# Plot distribution of top-1000 words

# %%
hist, edges = np.histogram(counts_ted_top1000, density=True, bins=100, normed=True)

# remember! we did: from bokeh.plotting import figure, show, output_file
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="621c71dd-7a8a-41ab-af9c-c38fe2950f04"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById
type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"d4c60112-9f91-4ba5-8532-adf64cfb8c56","type":"LinearAxis"}],"left":[{"id":"1425d898-7044-4ca2-b7c5-cf22a9da2c35","type":"LinearAxis"}],"renderers":[{"id":"d4c60112-9f91-4ba5-8532-adf64cfb8c56","type":"LinearAxis"},{"id":"1a35fe1f-96a5-4936-b460-539079c12bcf","type":"Grid"},{"id":"1425d898-7044-4ca2-b7c5-cf22a9da2c35","type":"LinearAxis"},{"id":"0110346a-20cb-40c1-9b64-88e4c5a7d583","type":"Grid"},{"id":"40c2630a-49c2-42e2-89eb-f6c8ff905a60","type":"GlyphRenderer"}],"title":{"id":"f612e41c-476f-4032-8e7a-97f4870cd49b","type":"Title"},"tool_events":{"id":"ef05cad1-d7ff-494d-b1fd-e2a94a99907b","type":"ToolEvents"},"toolbar":{"id":"d65026cf-1923-4116-90a4-aefc4931bcdc","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"0d98ce70-6f70-46d8- ...

# %% [markdown]
# ### Part 3: Train Word2Vec

# %%
from gensim.models import Word2Vec

# %%
model_ted = Word2Vec(sentences_ted, size=100, window=5, min_count=5, workers=4)

# %% [markdown]
# ### Simple SVD

# %%
sentences_ted_small = sentences_ted[0:1000]
text = [word for line in sentences_ted_small for word in line]
print(len(set(text)))
word_frequency = Counter(text)

# exclude high and low-frequency words
text = [word for word, count in word_frequency.items() if count > 1]
print(len(text))


vocabulary = sorted(list(set(text)))
word2index = {word: index for index, word in enumerate(vocabulary)}
# Out:
# 3067
# 1332

# %%
def make_data(sentences, vocabulary, window_size=5):
    data = list()
    for line in sentences:
        l = len(line)
        for k, word in enumerate(line):
            if word in vocabulary:
                for i in range(1, window_size+1):
                    try:
                        context = line[k+i]
                        score = 1./i
                        data.append((word, context, score))
                    except IndexError:
                        pass
                for i in range(-1, -(window_size+1), -1):
                    if k+i >  -1:
                        context = line[k+i]
                        score = 1./-i
                        data.append((word, context, score))                   
    return data
                                
def make_matrix(data, word2index, vocabulary):
    X = np.zeros((len(word2index), len(word2index)))
    for word1, word2, score in data:
        if word1 in vocabulary and word2 in vocabulary: 
            X[word2index[word1], word2index[word2]] += score
            X[word2index[word2], word2index[word1]] += score
    return X

data = make_data(sentences_ted_small, vocabulary)
X = make_matrix(data, word2index, vocabulary)

# %%
U, s, V = np.linalg.svd(X, full_matrices=True)

# %%
# select the first k columns of U
k = 100
reduced_U = U[:, 0:k]

vectors = {word: reduced_U[index,:] for word, index in word2index.items()}

print(cosine_similarity(vectors['man'], vectors['woman']))
# Out:
# [[ 0.09442345]]
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
words_top = [a for a,b in Counter((item for sublist in sentences_ted_small for item in sublist if item in vocabulary)).most_common(1000)]
words_top_vec = [vectors[word] for word in words_top]

# %%
from sklearn.cluster import KMeans

N=20
kmeans_LSA = KMeans(n_clusters=N)
kmeans_LSA.fit(words_top_vec)

klabels = kmeans_LSA.labels_

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_tsne = tsne.fit_transform(words_top_vec)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=words_top_tsne[:,0],
                                    x2=words_top_tsne[:,1],
                                    names=words_top,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="85d7f373-4ce3-446a-9e89-e68d4af9c25b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("85d7f373-4ce3-446a-9e89-e68d4af9c25b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85d7f373-4ce3-446a-9e89-e68d4af9c25b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85d7f373-4ce3-446a-9e89-e68d4af9c25b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"644597a0-8694-4c01-b995-8b02c0aa3917":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bb47f226-58ac-4d1b-9141-9116349196b5","type":"PanTool"},{"id":"cba5783d-7b9c-4e27-90dc-70a39b6e1500","type":"WheelZoomTool"},{"id":"d81b69eb-06d2-41fc-b8e4-c5fe86835582","type":"ResetTool"},{"id":"67722206-6265-41bb-a37f-8d7acbb84962","type":"SaveTool"}]},"id":"9c819f6b-8326-46e6-a6b2-a6300ed14048","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#9467bd","#aec7e8","#bcbd22","#98df8a","#aec7e8","#c49c94","#c7c7c7","#ff9896","#ffbb78","#aec7e8","#d62728","#7f7f7f","#7f7f7f","#7f7f7f","#dbdb8d","#aec7e8","#aec7e8","#aec7e8","#f7b6d2","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#8c564b","#aec7e8","#aec7e8","#e377c2","#aec7e8","#2ca02c","#aec7e8","#7f7f7f","#7f7f7f","#1f77b4","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#9edae5","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#c5b0d5","#7f7f7f","#aec7e8","#ff7f0e","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#17becf","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#17becf","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#7f7f7f","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#7f7f7f","#aec7e8","#aec7e8","#aec7e8","#aec7e8","#aec7e8","# ...

# %% [markdown]
# ### Part 4: Ted Learnt Representations

# %% [markdown]
# Finding similar words: (see gensim docs for more functionality of `most_similar`)

# %%
model_ted.most_similar("man")
# Out:
# [('woman', 0.8439397811889648),
#  ('guy', 0.8213635683059692),
#  ('lady', 0.7564780712127686),
#  ('boy', 0.74680495262146),
#  ('girl', 0.7457009553909302),
#  ('gentleman', 0.735012412071228),
#  ('soldier', 0.6953460574150085),
#  ('poet', 0.6822323799133301),
#  ('kid', 0.6808496117591858),
#  ('person', 0.6711852550506592)]

# %%
model_ted.most_similar("computer")
# Out:
# [('machine', 0.761170506477356),
#  ('software', 0.7403644919395447),
#  ('robot', 0.6885926723480225),
#  ('device', 0.6714223623275757),
#  ('chip', 0.6556211709976196),
#  ('satellite', 0.6545467376708984),
#  ('program', 0.6528584361076355),
#  ('video', 0.6496102809906006),
#  ('interface', 0.6489081382751465),
#  ('camera', 0.6370853185653687)]

# %%
from sklearn.metrics.pairwise import cosine_similarity
from pprint import pprint

pprint(model_ted.most_similar(positive=['woman', 'king'], negative=['man']))

man = model_ted.wv['man']
woman = model_ted.wv['woman']
king = model_ted.wv['king']
queen = model_ted.wv['queen']
president = model_ted.wv['president']
nelson = model_ted.wv['nelson']

res = king - man + woman
print('\nManually:')
print(cosine_similarity(res, president)[0][0])
print(cosine_similarity(res, queen)[0][0])
print(cosine_similarity(res, nelson)[0][0])
# Out:
# [('james', 0.7696994543075562),
#  ('president', 0.759020209312439),
#  ('french', 0.7584216594696045),
#  ('martin', 0.7516719102859497),
#  ('luther', 0.7492113709449768),
#  ('named', 0.7480069398880005),
#  ('obama', 0.7405663132667542),
#  ('poet', 0.7364769577980042),
#  ('queen', 0.7361757159233093),
#  ('charles', 0.718647301197052)]
#
# Manually:
# 0.639316
# 0.646932
# 0.581816
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
model_ted.most_similar(positive=['sex'], negative=['love'])
# Out:
# [('rates', 0.5779918432235718),
#  ('cancer', 0.575636625289917),
#  ('disease', 0.5671032071113586),
#  ('hiv', 0.5437273383140564),
#  ('breast', 0.5277000069618225),
#  ('treatment', 0.5191365480422974),
#  ('drug', 0.511942982673645),
#  ('males', 0.5072714686393738),
#  ('malaria', 0.5062967538833618),
#  ('flu', 0.4962305724620819)]

# %%
model_ted.most_similar(positive=['friend', 'sex'])
# Out:
# [('husband', 0.7259034514427185),
#  ('boyfriend', 0.7125725746154785),
#  ('physician', 0.6929498910903931),
#  ('daughter', 0.6927310228347778),
#  ('sister', 0.6858277320861816),
#  ('son', 0.678431510925293),
#  ('girlfriend', 0.6769047975540161),
#  ('mother', 0.675109326839447),
#  ('wife', 0.6746364235877991),
#  ('woman', 0.6739469766616821)]

# %%
sex = model_ted.wv['sex']
love = model_ted.wv['love']
disease = model_ted.wv['disease']
hiv = model_ted.wv['hiv']

res = sex - love
print(cosine_similarity(res, hiv)[0][0])
print(cosine_similarity(res, disease)[0][0])
# Out:
# 0.410936
# 0.453615
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /Users/daan/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %% [markdown]
# #### t-SNE visualization
# To use the t-SNE code below, first put a list of the top 1000 words (as strings) into a variable `words_top_ted`. The following code gets the corresponding vectors from the model, assuming it's called `model_ted`:

# %%
# This assumes words_top_ted is a list of strings, the top 1000 words
words_top_ted = [a for a,b in Counter((item for sublist in sentences_ted for item in sublist)).most_common(1000)]
words_top_vec_ted = model_ted[words_top_ted]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a9ee92d6-a7fc-45ed-8ab5-1b5451a5e17a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a9ee92d6-a7fc-45ed-8ab5-1b5451a5e17a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a9ee92d6-a7fc-45ed-8ab5-1b5451a5e17a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a9ee92d6-a7fc-45ed-8ab5-1b5451a5e17a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0feb36ce-91f5-44ef-948f-f9ad9ff0e1d1":{"roots":{"references":[{"attributes":{"plot":{"id":"0d8ce794-d5d4-431a-b707-41c5302e749d","subtype":"Figure","type":"Plot"}},"id":"fb44ef03-6298-4572-80a3-fa17b300c87b","type":"PanTool"},{"attributes":{},"id":"f49557ce-cbd1-4981-b772-a63686a475b9","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0d8ce794-d5d4-431a-b707-41c5302e749d","subtype":"Figure","type":"Plot"}},"id":"ebade4ab-7770-440f-9a99-dd32b3b60e76","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"1da90dd4-2288-40b5-94d0-5a0eb9e6e837","type":"Circle"},{"attributes":{"plot":{"id":"0d8ce794-d5d4-431a-b707-41c5302e749d","subtype":"Figure","type":"Plot"}},"id":"72a25e6b-a70d-4767-8449-0e6d2c535695","type":"ResetTool"},{"attributes":{"plot":{"id":"0d8ce794-d5d4-431a-b707-41c5302e749d","subtype":"Figure","type":"Plot"}},"id":"0d1d6ea3-5e0d-49a6-b633-4d055e7d795f","type":"SaveTool"},{"attributes":{"data_source":{"id":"c97e47e2-9ddf-4186-a38d-0c66d2c0cd60","type":"ColumnDataSource"},"glyph":{"id":"63d2b822-ed83-4b70-bd08-c57ca450a251","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1da90dd4-2288-40b5-94d0-5a0eb9e6e837","type":"Circle"},"selection_glyph":null},"id":"d7469237-4869-4a6f-a547-cc31124ed80f","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"5eacb0be-58f7-4062-b3ed-d3b76cac4b00","type":"LinearAxis"}],"left":[{"id":"c387f2ef-7aa4-4c0d-8c5c-4c1ac457182a","type":"LinearAxis"}],"renderers":[{"id":"5eacb0be-58f7-4062-b3ed-d3b76cac4b00","type":"LinearAxis"},{"id":"afe992c1-dadf-4963-bd84-0677724c79b4","type":"Grid"},{"id":"c387f2ef-7aa4-4c0d-8c5c-4c1ac457182a","type":"LinearAxis"},{"id":"b5d1240e-33ef-4958-b681-d375f615ca45","type":"Grid"},{"id":"d7469237-4869-4a6f-a547-cc31124ed80f","type":"GlyphRenderer"},{"id":"14959e32-6cff-4d99-bac1-465f37b88aca","type":"LabelSet"}],"title":{"id":"080aa29f-b5f1-429f-95b4-65e0e8b8fe8c","type":"Title"},"tool_events":{"id":"acdda86b-a907-4f2a-aeb1-b943f493e993","type":"ToolEvents"},"toolbar":{"id":"69f9a6f0-66ec-4a6a-aa8d-dc1b809fedd7","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"da580762-6845-4a96-8936-c375d9038563","type":"DataRange1d"},"y_range":{"id":"f6c1d80d-e34c-4bfa-8bef-596808f88915","type":"DataRange1d"}},"id":"0d8ce794-d5d4-431a-b707-41c5302e749d","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x1","x2","names"],"data":{"names":["the","and","to","of","a","that","i","in","it","you","we","is","s","this","so","they","was","for","are","have","but","what","on","with","can","t","about","there","be","as","at","all","not","do","my","one","re","people","like","if","from","now","our","he","an","just","these","or","when","because","very","me","out","by","them","how","know","up","going","had","more","think","who","were","see","your","their","which","would","here","really","get","ve","then","m","world","us","time","some","has","don","actually","into","way","where","will","years","things","other","no","could","go","well","want","been","make","right","she","said","something","those","first","two","than","much","also","look","new","thing","little","got","back","over","most","say","even","his","life","only","work","many","take","need","did","lot","kind","why","good","around","every","different","down","ll","let","her","through","same","being","come","d","day","year","three","use","doing","put","called","any","today","percent","made","after","thank","tell","great","human","find","didn","fact","talk","change","started","another","idea","big","last","own","before","its","never","should","better","give","thought","went","might","important","000","again","able","together","still","problem","off","next","part","course","system","him","does","each","start","show","long","ago","story","came","brain","few","bit","b ...

# %%
from bokeh.palettes import d3
from sklearn.cluster import KMeans

# Kmeans
N=20
kmeans = KMeans(n_clusters=N)
kmeans.fit(words_top_vec_ted)
klabels = kmeans.labels_


# TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted)


p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted))

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
# /Users/daan/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e2b858d-00ba-4e80-9920-d55b613701a9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8e2b858d-00ba-4e80-9920-d55b613701a9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c9f6ee71-bc21-4532-a8ed-4995cdfd05d6","subtype":"Figure","type":"Plot"}},"id":"2f266b56-1424-4274-afc0-7df2b88d5164","type":"ResetTool"},{"attributes":{"plot":{"id":"c9f6ee71-bc21-4532-a8ed-4995cdfd05d6","subtype":"Figure","type":"Plot"}},"id":"4db4f103-f709-45a1-9f52-6a279cbaae6c","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"ffdd3a4a-b335-4666-b48e-30a1eabd6467","type":"Circle"},{"attributes":{},"id":"ce20ee1e-ae7a-4095-ae3f-4f0a344bd71a","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words"},"id":"0bce65b3-21d9-41b0-b4b2-5a1ee725c90c","type":"Title"},{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"value":null},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"c59fa83c-7465-457c-aa95-c2afe1eee3be","type":"Circle"},{"attributes":{"callback":null,"column_names":["x ...

# %% [markdown]
# ### Part 5: Wiki Learnt Representations

# %% [markdown]
# Download dataset

# %%
if not os.path.isfile('wikitext-103-raw-v1.zip'):
    urllib.request.urlretrieve("https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-103-raw-v1.zip", filename="wikitext-103-raw-v1.zip")

# %%
with zipfile.ZipFile('wikitext-103-raw-v1.zip', 'r') as z:
    input_text = str(z.open('wikitext-103-raw/wiki.train.raw', 'r').read(), encoding='utf-8') # Thanks Robert Bastian

# %% [markdown]
# Preprocess sentences (note that it's important to remove small sentences for performance)

# %%
sentences_wiki = []
for line in input_text.split('\n'):
    s = [x for x in line.split('.') if x and len(x.split()) >= 5]
    sentences_wiki.extend(s)
    
for s_i in range(len(sentences_wiki)):
    sentences_wiki[s_i] = re.sub("[^a-z]", " ", sentences_wiki[s_i].lower())
    sentences_wiki[s_i] = re.sub(r'\([^)]*\)', '', sentences_wiki[s_i])
del input_text

# %%
# sample 1/5 of the data
shuffle(sentences_wiki)
print(len(sentences_wiki))
sentences_wiki = sentences_wiki[:int(len(sentences_wiki)/5)]
print(len(sentences_wiki))
# Out:
# 4267112
# 853422

# %%
sentences_wiki = [sent.split() for sent in sentences_wiki]

# %% [markdown]
# Now, repeat all the same steps that you performed above. You should be able to reuse essentially all the code.

# %%
model_wiki = Word2Vec(sentences_wiki, size=100, window=5, min_count=5, workers=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-8da76dc955c3> in <module>()
# ----> 1 model_wiki = Word2Vec(sentences_wiki, size=100, window=5, min_count=5, workers=4)
#
# /Users/daan/anaconda/lib/python3.6/site-packages/gensim/models/word2vec.py in __init__(self, sentences, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss)
#     503             self.build_vocab(sentences, trim_rule=trim_rule)
#     504             self.train(sentences, total_examples=self.corpus_count, epochs=self.iter,
# --> 505                        start_alpha=self.alpha, end_alpha=self.min_alpha)
#     506         else :
#     507             if trim_rule is not None :
#
# /Users/daan/anaconda/lib/python3.6/site-packages/gensim/models/word2vec.py in train(self, sentences, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss)
#     950
#     951         while unfinished_worker_count > 0:
# --> 952             report = progress_queue.get()  # blocks if workers too slow
#     953             if report is None:  # a thread reporting that it finished
#     954                 unfinished_worker_count -= 1
#
# /Users/daan/anaconda/lib/python3.6/queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# /Users/daan/anaconda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
model_wiki.most_similar("man")

# %%
model_wiki.most_similar(positive=['woman', 'king'], negative=['man'])
# Out:
# [('queen', 0.7265071868896484),
#  ('monarch', 0.7108858227729797),
#  ('prince', 0.676477313041687),
#  ('throne', 0.6482481360435486),
#  ('mary', 0.6202875375747681),
#  ('regent', 0.6151993274688721),
#  ('elizabeth', 0.6127544045448303),
#  ('tsar', 0.6063425540924072),
#  ('emperor', 0.6059826016426086),
#  ('bishop', 0.6025694608688354)]

# %%
model_wiki.most_similar(positive=['man', 'queen'], negative=['woman'])
# Out:
# [('king', 0.7076507806777954),
#  ('prince', 0.6358840465545654),
#  ('duke', 0.5716805458068848),
#  ('knights', 0.545556902885437),
#  ('knight', 0.5395258069038391),
#  ('princess', 0.5334649085998535),
#  ('palace', 0.5278916954994202),
#  ('viii', 0.5240129232406616),
#  ('iv', 0.5209602117538452),
#  ('lord', 0.5187605023384094)]

# %%
model_wiki.most_similar(positive=['sex'], negative=['love'])
# Out:
# [('prospective', 0.4609847664833069),
#  ('quotas', 0.42649537324905396),
#  ('undergone', 0.4003305435180664),
#  ('voter', 0.37856006622314453),
#  ('contracting', 0.37701520323753357),
#  ('sustainability', 0.3765066862106323),
#  ('licenses', 0.3758765459060669),
#  ('arisen', 0.3758372664451599),
#  ('gender', 0.37290969491004944),
#  ('algo', 0.3649490475654602)]

# %%
model_wiki.most_similar(positive=['death'])
# Out:
# [('disappearance', 0.6886148452758789),
#  ('resignation', 0.6372559666633606),
#  ('demise', 0.6323477625846863),
#  ('execution', 0.6285609006881714),
#  ('illness', 0.6206174492835999),
#  ('assassination', 0.6077213287353516),
#  ('dismissal', 0.6054128408432007),
#  ('accession', 0.5957808494567871),
#  ('downfall', 0.5953985452651978),
#  ('dying', 0.5870745182037354)]

# %%
model_wiki.most_similar(positive=['berlin','france'], negative=['germany'])
# Out:
# [('paris', 0.8069356679916382),
#  ('brussels', 0.7552647590637207),
#  ('vienna', 0.7283011674880981),
#  ('amsterdam', 0.7279530763626099),
#  ('stockholm', 0.7225955128669739),
#  ('copenhagen', 0.715408205986023),
#  ('cologne', 0.7087779641151428),
#  ('dublin', 0.6844438314437866),
#  ('prague', 0.683234453201294),
#  ('edinburgh', 0.6782914996147156)]

# %%
model_wiki.most_similar(positive=['reddish'])
# Out:
# [('yellowish', 0.9571259021759033),
#  ('brownish', 0.9516955614089966),
#  ('pale', 0.9460060000419617),
#  ('buff', 0.9338060617446899),
#  ('grayish', 0.9283660054206848),
#  ('blackish', 0.9241414070129395),
#  ('greyish', 0.921999454498291),
#  ('pinkish', 0.9107787013053894),
#  ('whitish', 0.9054883122444153),
#  ('bluish', 0.9026447534561157)]

# %%
model_wiki['man']
# Out:
# array([-1.34633195, -0.69663572,  0.93169844,  2.3914063 ,  0.4537349 ,
#         2.83949161, -1.42561281, -1.2275207 ,  0.02407678, -1.27962923,
#         3.07740378, -1.89856362,  0.80874604,  0.20455222,  0.19423801,
#        -0.66091394,  0.70650673, -0.16849819,  2.26593304, -2.62963438,
#         0.32983837,  1.19061947, -2.44846463, -0.52996856, -0.260921  ,
#        -0.57010502,  2.15463948,  0.18584307,  1.40571022,  0.57718676,
#         0.6916995 , -1.74978197,  1.36594403,  2.28695202, -0.20485578,
#        -1.29948664, -0.04567685, -0.90644616, -2.43518782, -0.03822666,
#         2.05136847,  0.41769001,  1.10867691,  2.56136823,  1.56916225,
#        -0.92679238,  1.56063342, -1.01675463,  0.3194547 , -0.27065817,
#        -2.11566257,  1.25215447,  0.251647  , -0.62749487,  1.05525768,
#        -0.47860861,  1.06391549,  0.9908092 ,  0.46771893, -0.96025306,
#        -3.72881556,  1.70448399, -0.22398096, -0.32391751,  1.2532177 ,
#         0.87568057, -0.73176992, -2.72126222,  1.04401469,  1.71216309,
#        -0.26534376, -1.0332247 ,  0.2694295 , -0.63835502, -1.39368379,
#         2.50021887, -0.76920551,  0.87996459,  1.35724914, -1.67216492,
#         0.94242197, -1.34410131, -0.19734426,  2.69871521,  1.25260293,
#        -2.29088998, -1.48220801, -0.31494144,  0.09481353,  0.27888834,
#        -1.94022739,  0.32730299,  0.13675348, -2.27328396,  0.27945644,
#        -0.71303606, -0.98003441, -1.22878814,  0.12342662,  2.26671124], dtype=float32)

# %% [markdown]
# #### t-SNE visualization

# %%
# This assumes words_top_wiki is a list of strings, the top 1000 words
words_top_wiki = [a for a,b in Counter((item for sublist in sentences_wiki for item in sublist)).most_common(1000)]
words_top_vec_wiki = model_wiki[words_top_wiki]

tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

# %%
tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="558a0955-117d-4c35-a526-501caac20dae"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("558a0955-117d-4c35-a526-501caac20dae").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("558a0955-117d-4c35-a526-501caac20dae");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '558a0955-117d-4c35-a526-501caac20dae' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f67abb07-3007-4f39-92e4-8bed33d356c0":{"roots":{"references":[{"attributes":{"below":[{"id":"09428de2-224d-429c-9c8e-b58c6a0f28b4","type":"LinearAxis"}],"left":[{"id":"12e168c1-0bff-4ada-8797-e41a31209bf7","type":"LinearAxis"}],"renderers":[{"id":"09428de2-224d-429c-9c8e-b58c6a0f28b4","type":"LinearAxis"},{"id":"36fe922e-d9b8-4efa-a7be-1aed56aa4fa2","type":"Grid"},{"id":"12e168c1-0bff-4ada-8797-e41a31209bf7","type":"LinearAxis"},{"id":"e7e14dd1-eae7-4f8a-9d0c-e7cdc0a590c0","type":"Grid"},{"id":"bbb1b898-fe35-403c-80a9-249f59b10868","type":"GlyphRenderer"},{"id":"ead2f1fb-af94-45b8-ac7e-814b5ed28f80","type":"LabelSet"}],"title":{"id":"ef419d90-ca13-43db-907c-f03fdaa4acf3","type":"Title"},"tool_events":{"id":"5573ac5c-ea7a-4de3-bb7e-1be6bb9d833c","type":"ToolEvents"},"toolbar":{"id":"1a0ae92e-665d-4df8-aef0-3e56395a95d2","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":
subtype":"Figure","type":"Plot"},"ticker":{"id":"e6fbc822-ca46-4c7e-94f5-a170ad668ac8","t ...

# %% [markdown]
# ### Directions

# %%
# This assumes words_top_wiki is a list of strings, the top 1000 words
# words_top_wiki = ['berlin', 'paris', 'madrid', 'rome', 'tokyo', 'moscow', 'ankara', 'amsterdam', 'vienna'] + \
#     ['germany', 'france', 'spain', 'italy', 'japan', 'russia', 'turkey', 'netherlands', 'austria']
    
# words_top_wiki = ['berlin', 'paris', 'madrid', 'rome'] + \
#     ['germany', 'france', 'spain', 'italy']
    
# words_top_wiki = ['walking', 'swimming'] + ['walked', 'swam']
    
words_top_wiki = ['chair', 'door', 'house', 'floor', 'room'] + ['chairs', 'doors', 'houses', 'floors', 'rooms']

words_top_vec_wiki = model_wiki[words_top_wiki]

tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

# %%
tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e180549e-404b-4022-9323-4de1a8a735c7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e180549e-404b-4022-9323-4de1a8a735c7").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e180549e-404b-4022-9323-4de1a8a735c7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e180549e-404b-4022-9323-4de1a8a735c7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4c725fcc-f075-4582-b98b-00fc4d1a8dd5":{"roots":{"references":[{"attributes":{"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"}},"id":"a2fc0f50-d298-40e7-9677-517a376410c2","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"}},"id":"59fc2f6d-4686-4ce8-9063-a28b890ece4d","type":"PanTool"},{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words"},"id":"2bc938b1-8306-4fde-90f3-04ce321d71b3","type":"Title"},{"attributes":{"callback":null},"id":"670101b5-0e31-42f2-b3f5-7e0323c4edbc","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"cbcb5c2d-018d-4de7-8076-8676e5619e2f","type":"Circle"},{"attributes":{},"id":"fc3c38c5-623a-40dd-aca7-11edf51b62c9","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"eac29579-9399-4b34-8c42-a94856a618a0","type":"Circle"},{"attributes":{"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"},"source":{"id":"c0725f34-a385-40ce-a992-a33808dbe3a8","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"cd4ff0db-f75a-4721-ace2-50f98ff038c3","type":"LabelSet"},{"attributes":{"dimension":1,"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc3c38c5-623a-40dd-aca7-11edf51b62c9","type":"BasicTicker"}},"id":"8bca9590-3c32-44eb-bd32-b1b91fc86096","type":"Grid"},{"attributes":{"formatter":{"id":"c0214411-5388-41fd-be03-34508d6666a3","type":"BasicTickFormatter"},"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"fc3c38c5-623a-40dd-aca7-11edf51b62c9","type":"BasicTicker"}},"id":"cceb1152-570b-4640-9341-304e79cb9432","type":"LinearAxis"},{"attributes":{},"id":"c0214411-5388-41fd-be03-34508d6666a3","type":"BasicTickFormatter"},{"attributes":{},"id":"e5fc0e11-eb38-4042-883b-76c3b650aa0b","type":"BasicTicker"},{"attributes":{"below":[{"id":"faeb895d-b043-431d-81e8-c8d5774297a0","type":"LinearAxis"}],"left":[{"id":"cceb1152-570b-4640-9341-304e79cb9432","type":"LinearAxis"}],"renderers":[{"id":"faeb895d-b043-431d-81e8-c8d5774297a0","type":"LinearAxis"},{"id":"2dcf0612-2010-4640-bb7b-b88fa46da082","type":"Grid"},{"id":"cceb1152-570b-4640-9341-304e79cb9432","type":"LinearAxis"},{"id":"8bca9590-3c32-44eb-bd32-b1b91fc86096","type":"Grid"},{"id":"dd12fba3-5db5-47e1-ad4a-a8d6f01f04ad","type":"GlyphRenderer"},{"id":"cd4ff0db-f75a-4721-ace2-50f98ff038c3","type":"LabelSet"}],"title":{"id":"2bc938b1-8306-4fde-90f3-04ce321d71b3","type":"Title"},"tool_events":{"id":"62e04ad0-5172-4e28-bd50-39b72e699ef3","type":"ToolEvents"},"toolbar":{"id":"b65d40cd-d466-4b44-a3b1-50e21d322362","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"63b7c2a7-bf20-4ee6-bec9-1b617085288a","type":"DataRange1d"},"y_range":{"id":"670101b5-0e31-42f2-b3f5-7e0323c4edbc","type":"DataRange1d"}},"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5fc0e11-eb38-4042-883b-76c3b650aa0b","type":"BasicTicker"}},"id":"2dcf0612-2010-4640-bb7b-b88fa46da082","type":"Grid"},{"attributes":{},"id":"62e04ad0-5172-4e28-bd50-39b72e699ef3","type":"ToolEvents"},{"attributes":{"plot":{"id":"b3e9f252-5c95-4a48-b817-8f100bd21dd1","subtype":"Figure","type":"Plot"}},"id":"9174253f-e970-4a39-bf00-64b70932df7f","type":"SaveTool"},{"attributes":{},"id":"07408573-64f9-41b4-8f69-65abcd644824","type" ...

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans

words_top_wiki = [a for a,b in Counter((item for sublist in sentences_wiki for item in sublist)).most_common(500)]
words_top_vec_wiki = model_wiki[words_top_wiki]

N=20
kmeans = KMeans(n_clusters=N)
kmeans.fit(words_top_vec_wiki)

# %%
klabels = kmeans.labels_
# pprint(labels)

# %%
from collections import defaultdict
from pprint import pprint

clusters = defaultdict(list)

for k, label in enumerate(klabels):
    clusters[label].append(words_top_wiki[k])

pprint(clusters)

# %%
from bokeh.palettes import d3


tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki))

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
# /Users/daan/anaconda/lib/python3.6/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d96d3c7f-fed2-41dd-b022-1f1994cab986"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d96d3c7f-fed2-41dd-b022-1f1994cab986").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d96d3c7f-fed2-41dd-b022-1f1994cab986");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd96d3c7f-fed2-41dd-b022-1f1994cab986' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7bdb8e3-5e4d-4e77-a4b3-42cfc4db8c64":{"roots":{"references":[{"attributes":{"data_source":{"id":"9d56fb00-ce7e-4341-835f-b610b1e30c39","type":"ColumnDataSource"},"glyph":{"id":"e82fecc6-a5d2-4dad-9bc7-edaf0727504d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":
type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"821c9713-73da-4e0e-bfcd-ac399c46ec88","type":"Circle"},{"attributes":{},"id":"ce43c500-6910-4feb-9723-7de83dfe1182","type":"BasicTicker"},{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"value":null},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"e82fecc6-a5d2-4dad-9bc7-edaf0727504d","type":"Circle"},{"attributes":{"callback":null,"column_names":["x1","x2","names","fill_color"],"data":{"fill_color":["#c7c7c7","#c7c7c7","#c7c7c7","#c7c7c7","#d62728","#9467bd","#dbdb8d","#c7c7c7","#e377c2","#c7c7c7","#c7c7c7","#c5 ...

# %% [markdown]
# #### TedX

# %%
words_top_ted = [a for a,b in Counter((item for sublist in sentences_ted for item in sublist)).most_common(500)]
words_top_vec_ted = model_ted[words_top_ted]

N=20
ted_kmeans = KMeans(n_clusters=N)
ted_kmeans.fit(words_top_vec_ted)

klabels = ted_kmeans.labels_

# %%
from bokeh.palettes import d3

tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted)

# # PCA
# pca = PCA(n_components=2)
# X = np.vstack(words_top_vec_ted)
# words_top_ted_pca = pca.fit_transform(np.vstack(X))

# %%
# p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
#                                     x2=words_top_ted_tsne[:,1],
#                                     names=words_top_ted))

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec PCA for most common words")

# source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
#                                     x2=words_top_ted_tsne[:,1],
#                                     names=words_top_ted))

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=words_top_ted_pca[:,0],
                                    x2=words_top_ted_pca[:,1],
                                    names=words_top_ted,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)

# %% [markdown]
# ### Comparison with pretrained GloVe vectors

# %%
words_top_ted_glove = []
words_top_vec_ted_glove = []

with open('glove.6B.100d.txt', 'r') as f:
    for line in f:
        line = line.split()
        word, vector = line[0], np.array(list(map(float, line[1:])))
        if word in words_top_ted:
            words_top_ted_glove.append(word)
            words_top_vec_ted_glove.append(vector)
            
len(words_top_ted_glove)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-783-9a4454b1b24e> in <module>()
#       5     for line in f:
#       6         line = line.split()
# ----> 7         word, vector = line[0], np.array(list(map(float, line[1:])))
#       8         if word in words_top_ted:
#       9             words_top_ted_glove.append(word)
#
# KeyboardInterrupt:

# %%
N=20
ted_kmeans = KMeans(n_clusters=N)
ted_kmeans.fit(words_top_vec_ted_glove)

klabels = ted_kmeans.labels_

# %%
from bokeh.palettes import d3

tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted_glove)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted_glove,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4a486b25-e506-408d-854d-420953863761"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4a486b25-e506-408d-854d-420953863761").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4
b78","#ff9896","#bcbd22","#17becf","#1f77b4","#ffbb78","#c7c7c7","#c7c7c7","#bcbd22","#9467bd","#ffbb78","#1f77b4","#ff9896","#bcbd22","#8c564b","#9467bd","#bcbd22","#ff9896","#bcbd22","#c7c7c7","#ff9896","#1f77b4","#17becf","#bcbd22","#17becf","#9467bd","#bcbd22","#ff9896","#bcbd22","#bcbd22","#bcbd22","#c7c7c7","#c7c7c7","#bcbd22","#17becf","#7f7f7f","#bcbd22","#1f77b4","#ff9896","#ffbb78","#bcbd22","#bcbd22","#9edae5","#17becf","#17becf","#dbdb8d","#bcbd22","#c7c7c7","#aec7e8","#ffbb78","#17becf","#aec7e8","#bcbd22","#aec7e8","#aec7e8","#bcbd22","#ff9896","#c7c7c7","#bcbd22","#c7c7c7","#bcbd22","#bcbd22","#1f77b4","#ff9896","#aec7e8","#ff9896","#7f7f7f","#8c564b","#dbdb8d","#d62728","#aec7e8","#17becf","#aec7e8","#e377c2","#17becf","#7f7f7f","#aec7e8","#aec7e8","#ffbb78","#9edae5","#7f7f7f","#9edae5","#ff9896","#aec7e8","#c7c7c7","#94 ...

# %%
superlatives = 'slow slower slowest strong stronger strongest short shorter shortest loud louder loudest soft softer softest dark darker darkest'.split()

# %%
def read_glove(words):
    vectors = []
    with open('glove.6B.100d.txt', 'r') as f:
        for line in f:
            line = line.split()
            word, vector = line[0], np.array(list(map(float, line[1:])))
            if word in words:
                vectors.append(vector)
    return vectors

superlatives_vec = read_glove(superlatives)

# %%
print(superlatives_vec)
# Out:
# [array([ 0.02485  ,  0.59314  , -0.12781  , -0.35143  ,  0.023261 ,
#        -0.39481  , -0.48087  , -0.79829  , -0.81172  , -0.19067  ,
#        -0.3143   , -0.54082  ,  0.095826 , -0.16637  ,  0.12769  ,
#         0.14948  , -0.6227   , -0.39135  ,  0.13587  ,  0.59116  ,
#         0.75629  ,  0.16022  ,  0.069661 ,  0.44891  ,  0.005979 ,
#        -0.2585   , -0.065012 , -0.16927  , -0.14908  ,  0.25327  ,
#         0.062652 ,  0.41622  , -0.10071  , -0.080752 ,  0.3801   ,
#        -0.15321  ,  0.54417  ,  0.052613 ,  0.035828 ,  0.25523  ,
#        -0.26824  , -0.27357  ,  0.70679  , -0.27775  ,  0.39379  ,
#        -0.63025  ,  0.69693  , -0.031248 ,  0.36064  , -1.4661   ,
#         0.0036175, -0.1279   ,  0.22016  ,  0.5064   ,  0.71714  ,
#        -2.7891   ,  0.67664  , -0.4229   ,  1.7797   , -0.13968  ,
#         0.082667 ,  0.40518  , -0.70116  ,  0.61516  ,  0.36789  ,
#         0.0063677,  0.12776  ,  0.05621  ,  0.56395  , -0.5049   ,
#         0.66133  ,  0.057792 , -0.2199   , -0.56177  ,  0.56358  ,
#         0.25459  , -0.35633  , -0.4834   , -0.57473  , -0.023526 ,
#         0.5016   , -0.063746 , -0.82133  ,  0.11984  , -0.87571  ,
#        -0.79299  , -0.087786 ,  0.41557  , -0.25616  , -0.81664  ,
#         0.18257  , -0.05376  , -0.46392  ,  0.3245   , -0.32427  ,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-efe302544086> in <module>()
#       1 N=3
#       2 ted_kmeans = KMeans(n_clusters=N)
# ----> 3 ted_kmeans.fit(superlatives_vec)
#       4
#       5 klabels = ted_kmeans.labels_
#
# NameError: name 'superlatives_vec' is not defined

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=superlatives_tsne[:,0],
                                    x2=superlatives_tsne[:,1],
                                    names=superlatives,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="818df9f7-e71d-429f-b4ad-1c05a1d9162d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("818df9f7-e71d-429f-b4ad-1c05a1d9162d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("818df9f7-e71d-429f-b4ad-1c05a1d9162d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '818df9f7-e71d-429f-b4ad-1c05a1d9162d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b96bf16d-a7c5-49ad-bed0-02195d9dd6f5":{"roots":{"references":[{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"},"source":{"id":"ad7273eb-3940-4c9b-bc4b-744c11ad4fe3","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"16afbd95-3a99-4276-b32b-2a62ba1967d7","type":"LabelSet"},{"attributes":{"formatter":{"id":"bbb6c3f3-5ddb-4549-bb8c-877826d1f1b3","type":"BasicTickFormatter"},"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a44ccd8-98e1-4a8c-9318-c4c5a8282069","type":"BasicTicker"}},"id":"eb7c558c-1a2a-4d7e-bb2c-c76b645edb24","type":"LinearAxis"},{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"}},"id":"40b0afc4-0b4f-444e-ac19-697a1994649d","type":"SaveTool"},{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words"},"id":"1654147a-a3b0-4bf7-96b7-fe9fc55b5648","type":"Title"},{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a44ccd8-98e1-4a8c-9318-c4c5a8282069","type":"BasicTicker"}},"id":"ba7ee370-96d7-4081-b5ed-30ad04785e72","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f5c2ccd6-14bb-4526-9b30-b5c313b7d092","type":"PanTool"},{"id":"7319b510-6c1b-4055-a4ee-5170a0a31f07","type":"WheelZoomTool"},{"id":"27a38c78-41f8-4c89-ba3a-a0eb05076055","type":"ResetTool"},{"id":"40b0afc4-0b4f-444e-ac19-697a1994649d","type":"SaveTool"}]},"id":"71083784-b9c8-4830-841e-8394d0fc428f","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#aec7e8","#aec7e8","#aec7e8","#ff7f0e","#aec7e8","#ff7f0e"],"names":["slow","slower","slowest","strong","stronger","strongest"],"x1":{"__ndarray__":"7K3hVKMUJz834yjBm5UZP00FWi5yYig/0OcHtZHbGD9PBy782mLlvlvMgX1ceO4+","dtype":"float64","shape":[6]},"x2":{"__ndarray__":"K57QB3r0BD+Y8M+GfTUtP5CCvydVgBm/9Oc57MeT7740HTExi4gFP64Ury+y/CI/","dtype":"float64","shape":[6]}}},"id":"ad7273eb-3940-4c9b-bc4b-744c11ad4fe3","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"b6a23471-4903-4bcb-a906-895207209002","type":"DataRange1d"},{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"}},"id":"27a38c78-41f8-4c89-ba3a-a0eb05076055","type":"ResetTool"},{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"}},"id":"7319b510-6c1b-4055-a4ee-5170a0a31f07","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"}},"id":"f5c2ccd6-14bb-4526-9b30-b5c313b7d092","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"ff0ef74d-e1d1-4d57-baa0-d5cea6e517a2","subtype":"Figure","type":"Plot"},"ticker":{"id":"a194447e-946a-4909-9c9f-a640ccff11a1","type":"BasicTicker"}},"id":"6852a1e8-7d9c-4c0d-b25c-b404ef34ddc9","type":"Grid"},{"attributes":{"below":[{"id":"eb7c558c-1a2a-4d7e-bb2c-c76b645edb24","type":"LinearAxis"}],"left":[{"id":"35897e90-d4be-4193-b6aa-19e7e7b8a649","type":"LinearAxis"}],"renderers":[{"id":"eb7c558c-1a2a-4d7e-bb2c-c76b645edb24","type":"LinearAxis"},{"id":"ba7ee370-96d7-4081-b5ed-30ad04785e72","type":"Grid"},{"id":"35897e90-d4be-4193-b6aa-19e7e7b8a649","type":"LinearAxis"},{"id":"6852a1e8-7d9c-4c0d-b25c-b404ef34ddc9","type":"Grid"},{"id":"1174ba8f-9ff2-4266-b01a-e4fed172bd8b","type":"GlyphRenderer"},{"id":"16afbd95-3a99-4276-b32b-2a62ba1967d7","type":"LabelSet"}],"title":{"id":"1654147a-a3b0-4bf7-96b7-fe9fc55b5648","type":"Title"},"tool_events":{"id":"97037085-62a6-434a-8997-b25b9e76d96d","type":"ToolEvents"},"toolbar":{"id":"71083784-b9c8-4830-841e-8394d0fc428f","type":"Toolbar"},"toolbar_location":"above","x_range":{"id": ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

X = np.vstack(superlatives_vec)
superlatives_pca = pca.fit_transform(np.vstack(X))

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[i] for i in klabels]

source = ColumnDataSource(data=dict(x1=superlatives_pca[:,0],
                                    x2=superlatives_pca[:,1],
                                    names=superlatives,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8036c061-633f-47d7-b93e-29ced35b06eb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("8036c061-633f-47d7-b93e-29ced35b06eb").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8036c061-633f-47d7-b93e-29ced35b06eb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8036c061-633f-47d7-b93e-29ced35b06eb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"23c8cf4b-8ee4-47a4-a310-1e8aece30207":{"roots":{"references":[{"attributes":{"plot":{"id":"f929bc56-eed8-449d-a724-68c6332f2523","subtype":"Figure","type":"Plot"},"source":{"id":"5a6df9fa-3282-4b9a-a71b-b19959631781","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"fa1d0e6a-d45b-464e-b283-0f458609d0ed","type":"LabelSet"},{"attributes":{},"id":"41f8cfbf-f194-4789-a3fd-a6d1bf30ea8c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"
Av8/","dtype":"float64","shape":[18]},"x2":{"__ndarray__":"8t1vTHQJ6b9F1zZOhVzvPx8NX8BzKfO/OrK7puVKDkCktPP01/P1v1xoh/KWevo/updmFbBJ+r/Pof9WH+erP7ip3+GthwDAl2RDk3bd4z/yfzIl2cwJQHYEXN8T4uk/x7O+4I0M4b+B4bgLJa/yv+wfMYtSdArAEU8NCYL8+T+Y6o5pHuH0v2KRS4TTzOM/","dtype":"float64","shape":[18]}}},"id":"5a6df9fa-3282-4b9a-a71b-b19959631781","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"da4f3f9e-d817-4aff-a025-81f6deea0097","type":"LinearAxis"}],"left":[{"id":"3dc1ac7d-f200-47ff-80f4- ...

# %% [markdown]
# ### Context vectors

# %%
business = sentences_ted[0:100]

# %%
jail = sentences_ted[900:1000]

# %%
def make_data(sentences, window_size=10):
    data = list()
    for line in sentences:
        for k, word in enumerate(line):
            min_id = max(0, k-window_size)
            max_id = min(k+window_size, len(line))
            context = line[min_id:k] + line[k+1:max_id]
            data.append(context)
    return data

business_contexts = make_data(business)
jail_contexts = make_data(jail)

business_contexts
# Out:
# [['are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more'],
#  ['here',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of'],
#  ['here',
#   'are',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the'],
#  ['here',
#   'are',
#   'two',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what',
#   's'],
#  ['here',
#   'are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['are',
#   'two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['two',
#   'reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['reasons',
#   'companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'they',
#   'only',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['companies',
#   'fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'only',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['fail',
#   'they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'do',
#   'what',
#   's',
#   'new'],
#  ['they',
#   'only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'what',
#   's',
#   'new'],
#  ['only',
#   'do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   's',
#   'new'],
#  ['do',
#   'more',
#   'of',
#   'the',
#   'same',
#   'or',
#   'they',
#   'only',
#   'do',
#   'what',
#   'new'],
#  ['more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's'],
#  ['me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is'],
#  ['to',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring'],
#  ['to',
#   'me',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and'],
#  ['to',
#   'me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['me',
#   'the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['the',
#   'real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['real',
#   'real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['real',
#   'solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'two',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['solution',
#   'to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'activities',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['to',
#   'quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'exploration',
#   'and',
#   'exploitation'],
#  ['quality',
#   'growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'and',
#   'exploitation'],
#  ['growth',
#   'is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'exploitation'],
#  ['is',
#   'figuring',
#   'out',
#   'the',
#   'balance',
#   'between',
#   'two',
#   'activities',
#   'exploration',
#   'and'],
#  ['are', 'necessary', 'but', 'it', 'can', 'be', 'too', 'much', 'of'],
#  ['both', 'necessary', 'but', 'it', 'can', 'be', 'too', 'much', 'of', 'a'],
#  ['both', 'are', 'but', 'it', 'can', 'be', 'too', 'much', 'of', 'a', 'good'],
#  ['both',
#   'are',
#   'necessary',
#   'it',
#   'can',
#   'be',
#   'too',
#   'much',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'can',
#   'be',
#   'too',
#   'much',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'be',
#   'too',
#   'much',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'too',
#   'much',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'be',
#   'much',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'be',
#   'too',
#   'of',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'be',
#   'too',
#   'much',
#   'a',
#   'good',
#   'thing'],
#  ['both',
#   'are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'be',
#   'too',
#   'much',
#   'of',
#   'good',
#   'thing'],
#  ['are',
#   'necessary',
#   'but',
#   'it',
#   'can',
#   'be',
#   'too',
#   'much',
#   'of',
#   'a',
#   'thing'],
#  ['necessary', 'but', 'it', 'can', 'be', 'too', 'much', 'of', 'a', 'good'],
#  ['facit'],
#  ['consider'],
#  ['m', 'actually', 'old', 'enough', 'to', 'remember', 'them'],
#  ['i', 'actually', 'old', 'enough', 'to', 'remember', 'them'],
#  ['i', 'm', 'old', 'enough', 'to', 'remember', 'them'],
#  ['i', 'm', 'actually', 'enough', 'to', 'remember', 'them'],
#  ['i', 'm', 'actually', 'old', 'to', 'remember', 'them'],
#  ['i', 'm', 'actually', 'old', 'enough', 'remember', 'them'],
#  ['i', 'm', 'actually', 'old', 'enough', 'to', 'them'],
#  ['i', 'm', 'actually', 'old', 'enough', 'to', 'remember'],
#  ['was', 'a', 'fantastic', 'company'],
#  ['facit', 'a', 'fantastic', 'company'],
#  ['facit', 'was', 'fantastic', 'company'],
#  ['facit', 'was', 'a', 'company'],
#  ['facit', 'was', 'a', 'fantastic'],
#  ['were', 'born', 'deep', 'in', 'the', 'swedish', 'forest', 'and', 'they'],
#  ['they',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made'],
#  ['they',
#   'were',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the'],
#  ['they',
#   'were',
#   'born',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['they',
#   'were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['were',
#   'born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['born',
#   'deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'mechanical',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['deep',
#   'in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'calculators',
#   'in',
#   'the',
#   'world'],
#  ['in',
#   'the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'in',
#   'the',
#   'world'],
#  ['the',
#   'swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'the',
#   'world'],
#  ['swedish',
#   'forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'world'],
#  ['forest',
#   'and',
#   'they',
#   'made',
#   'the',
#   'best',
#   'mechanical',
#   'calculators',
#   'in',
#   'the'],
#  ['used', 'them'],
#  ['everybody', 'them'],
#  ['everybody', 'used'],
#  ['what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came'],
#  ['and',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along'],
#  ['and',
#   'what',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they'],
#  ['and',
#   'what',
#   'did',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['and',
#   'what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['what',
#   'did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'continued',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['did',
#   'facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'doing',
#   'exactly',
#   'the',
#   'same'],
#  ['facit',
#   'do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'exactly',
#   'the',
#   'same'],
#  ['do',
#   'when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'the',
#   'same'],
#  ['when',
#   'the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'same'],
#  ['the',
#   'electronic',
#   'calculator',
#   'came',
#   'along',
#   'they',
#   'continued',
#   'doing',
#   'exactly',
#   'the'],
#  ['six', 'months', 'they', 'went', 'from', 'maximum', 'revenue'],
#  ['in', 'months', 'they', 'went', 'from', 'maximum', 'revenue'],
#  ['in', 'six', 'they', 'went', 'from', 'maximum', 'revenue'],
#  ['in', 'six', 'months', 'went', 'from', 'maximum', 'revenue'],
#  ['in', 'six', 'months', 'they', 'from', 'maximum', 'revenue'],
#  ['in', 'six', 'months', 'they', 'went', 'maximum', 'revenue'],
#  ['in', 'six', 'months', 'they', 'went', 'from', 'revenue'],
#  ['in', 'six', 'months', 'they', 'went', 'from', 'maximum'],
#  ['they', 'were', 'gone'],
#  ['and', 'were', 'gone'],
#  ['and', 'they', 'gone'],
#  ['and', 'they', 'were'],
#  [],
#  ['me', 'the', 'irony', 'about', 'the', 'facit', 'story', 'is', 'hearing'],
#  ['to',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about'],
#  ['to',
#   'me',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the'],
#  ['to',
#   'me',
#   'the',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small'],
#  ['to',
#   'me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic'],
#  ['me',
#   'the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators'],
#  ['the',
#   'irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in'],
#  ['irony',
#   'about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan'],
#  ['about',
#   'the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that'],
#  ['the',
#   'facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they'],
#  ['facit',
#   'story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used'],
#  ['story',
#   'is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to'],
#  ['is',
#   'hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double'],
#  ['hearing',
#   'about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check'],
#  ['about',
#   'the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their'],
#  ['the',
#   'facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['facit',
#   'engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['engineers',
#   'who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['who',
#   'had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['had',
#   'bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'to',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['bought',
#   'cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'double',
#   'check',
#   'their',
#   'calculators'],
#  ['cheap',
#   'small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'check',
#   'their',
#   'calculators'],
#  ['small',
#   'electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'their',
#   'calculators'],
#  ['electronic',
#   'calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'calculators'],
#  ['calculators',
#   'in',
#   'japan',
#   'that',
#   'they',
#   'used',
#   'to',
#   'double',
#   'check',
#   'their'],
#  ['did', 'too', 'much', 'exploitation'],
#  ['facit', 'too', 'much', 'exploitation'],
#  ['facit', 'did', 'much', 'exploitation'],
#  ['facit', 'did', 'too', 'exploitation'],
#  ['facit', 'did', 'too', 'much'],
#  ['exploration', 'can', 'go', 'wild', 'too'],
#  ['but', 'can', 'go', 'wild', 'too'],
#  ['but', 'exploration', 'go', 'wild', 'too'],
#  ['but', 'exploration', 'can', 'wild', 'too'],
#  ['but', 'exploration', 'can', 'go', 'too'],
#  ['but', 'exploration', 'can', 'go', 'wild'],
#  ['few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european'],
#  ['a',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech'],
#  ['a',
#   'few',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'alongside',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'a',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'european',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'biotech',
#   'company'],
#  ['a',
#   'few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'company'],
#  ['few',
#   'years',
#   'back',
#   'i',
#   'worked',
#   'closely',
#   'alongside',
#   'a',
#   'european',
#   'biotech'],
#  ['s', 'call', 'them', 'oncosearch'],
#  ['let', 'call', 'them', 'oncosearch'],
#  ['let', 's', 'them', 'oncosearch'],
#  ['let', 's', 'call', 'oncosearch'],
#  ['let', 's', 'call', 'them'],
#  ['company', 'was', 'brilliant'],
#  ['the', 'was', 'brilliant'],
#  ['the', 'company', 'brilliant'],
#  ['the', 'company', 'was'],
#  ['had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain'],
#  ['they',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms'],
#  ['they',
#   'had',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of'],
#  ['they',
#   'had',
#   'applications',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'certain',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'forms',
#   'of',
#   'blood',
#   'cancer'],
#  ['they',
#   'had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'of',
#   'blood',
#   'cancer'],
#  ['had',
#   'applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'blood',
#   'cancer'],
#  ['applications',
#   'that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'cancer'],
#  ['that',
#   'promised',
#   'to',
#   'diagnose',
#   'even',
#   'cure',
#   'certain',
#   'forms',
#   'of',
#   'blood'],
#  ['day', 'was', 'about', 'creating', 'something', 'new'],
#  ['every', 'was', 'about', 'creating', 'something', 'new'],
#  ['every', 'day', 'about', 'creating', 'something', 'new'],
#  ['every', 'day', 'was', 'creating', 'something', 'new'],
#  ['every', 'day', 'was', 'about', 'something', 'new'],
#  ['every', 'day', 'was', 'about', 'creating', 'new'],
#  ['every', 'day', 'was', 'about', 'creating', 'something'],
#  ['were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we'],
#  ['they',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only'],
#  ['they',
#   'were',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get'],
#  ['they',
#   'were',
#   'extremely',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want',
#   'it'],
#  ['they',
#   'were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['were',
#   'extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['extremely',
#   'innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['innovative',
#   'and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'or',
#   'even',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['and',
#   'the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'even',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['the',
#   'mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'we',
#   'want',
#   'it',
#   'perfect'],
#  ['mantra',
#   'was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'want',
#   'it',
#   'perfect'],
#  ['was',
#   'when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'it',
#   'perfect'],
#  ['when',
#   'we',
#   'only',
#   'get',
#   'it',
#   'right',
#   'or',
#   'even',
#   'we',
#   'want',
#   'perfect'],
#  ['we', 'only', 'get', 'it', 'right', 'or', 'even', 'we', 'want', 'it'],
#  ['sad', 'thing', 'is', 'before', 'they', 'became', 'perfect', 'even', 'good'],
#  ['the',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough'],
#  ['the',
#   'sad',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they'],
#  ['the',
#   'sad',
#   'thing',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'good',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'enough',
#   'they',
#   'became',
#   'obsolete'],
#  ['the',
#   'sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'they',
#   'became',
#   'obsolete'],
#  ['sad',
#   'thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'became',
#   'obsolete'],
#  ['thing',
#   'is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'obsolete'],
#  ['is',
#   'before',
#   'they',
#   'became',
#   'perfect',
#   'even',
#   'good',
#   'enough',
#   'they',
#   'became'],
#  ['did', 'too', 'much', 'exploration'],
#  ['oncosearch', 'too', 'much', 'exploration'],
#  ['oncosearch', 'did', 'much', 'exploration'],
#  ['oncosearch', 'did', 'too', 'exploration'],
#  ['oncosearch', 'did', 'too', 'much'],
#  ['first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years'],
#  ['i',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago'],
#  ['i',
#   'first',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when'],
#  ['i',
#   'first',
#   'heard',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at'],
#  ['i',
#   'first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford'],
#  ['first',
#   'heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['heard',
#   'about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['about',
#   'exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['exploration',
#   'and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['and',
#   'exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['exploitation',
#   'about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'scholar',
#   'at',
#   'stanford',
#   'university'],
#  ['about',
#   '15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'at',
#   'stanford',
#   'university'],
#  ['15',
#   'years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'stanford',
#   'university'],
#  ['years',
#   'ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'university'],
#  ['ago',
#   'when',
#   'i',
#   'worked',
#   'as',
#   'a',
#   'visiting',
#   'scholar',
#   'at',
#   'stanford'],
#  ['founder', 'of', 'the', 'idea', 'is', 'jim', 'march'],
#  ['the', 'of', 'the', 'idea', 'is', 'jim', 'march'],
#  ['the', 'founder', 'the', 'idea', 'is', 'jim', 'march'],
#  ['the', 'founder', 'of', 'idea', 'is', 'jim', 'march'],
#  ['the', 'founder', 'of', 'the', 'is', 'jim', 'march'],
#  ['the', 'founder', 'of', 'the', 'idea', 'jim', 'march'],
#  ['the', 'founder', 'of', 'the', 'idea', 'is', 'march'],
#  ['the', 'founder', 'of', 'the', 'idea', 'is', 'jim'],
#  ['to', 'me', 'the', 'power', 'of', 'the', 'idea', 'is', 'its'],
#  ['and',
#   'me',
#   'the',
#   'power',
#   'of',
#   'the',
#   'idea',
#   'is',
#   'its',
#   'practicality'],
#  ['and',
#   'to',
#   'the',
#   'power',
#   'of',
#   'the',
#   'idea',
#   'is',
#   'its',
#   'practicality'],
#  ['and',
#   'to',
#   'me',
#   'power',
#   'of',
#   'the',
#   'idea',
#   'is',
#   'its',
#   'practicality'],
#  ['and', 'to', 'me', 'the', 'of', 'the', 'idea', 'is', 'its', 'practicality'],
#  ['and',
#   'to',
#   'me',
#   'the',
#   'power',
#   'the',
#   'idea',
#   'is',
#   'its',
#   'practicality'],
#  ['and',
#   'to',
#   'me',
#   'the',
#   'power',
#   'of',
#   'idea',
#   'is',
#   'its',
#   'practicality'],
#  ['and', 'to', 'me', 'the', 'power', 'of', 'the', 'is', 'its', 'practicality'],
#  ['and',
#   'to',
#   'me',
#   'the',
#   'power',
#   'of',
#   'the',
#   'idea',
#   'its',
#   'practicality'],
#  ['and',
#   'to',
#   'me',
#   'the',
#   'power',
#   'of',
#   'the',
#   'idea',
#   'is',
#   'practicality'],
#  ['and', 'to', 'me', 'the', 'power', 'of', 'the', 'idea', 'is', 'its'],
#  [],
#  ['is', 'about', 'coming', 'up', 'with', 'what', 's', 'new'],
#  ['exploration', 'about', 'coming', 'up', 'with', 'what', 's', 'new'],
#  ['exploration', 'is', 'coming', 'up', 'with', 'what', 's', 'new'],
#  ['exploration', 'is', 'about', 'up', 'with', 'what', 's', 'new'],
#  ['exploration', 'is', 'about', 'coming', 'with', 'what', 's', 'new'],
#  ['exploration', 'is', 'about', 'coming', 'up', 'what', 's', 'new'],
#  ['exploration', 'is', 'about', 'coming', 'up', 'with', 's', 'new'],
#  ['exploration', 'is', 'about', 'coming', 'up', 'with', 'what', 'new'],
#  ['exploration', 'is', 'about', 'coming', 'up', 'with', 'what', 's'],
#  ['s', 'about', 'search', 'it', 's', 'about', 'discovery', 'it', 's'],
#  ['it',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about'],
#  ['it',
#   's',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new'],
#  ['it',
#   's',
#   'about',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products'],
#  ['it',
#   's',
#   'about',
#   'search',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   's',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'new'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['it',
#   's',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['s',
#   'about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'products',
#   'it',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['about',
#   'search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'it',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['search',
#   'it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   's',
#   'about',
#   'new',
#   'innovations'],
#  ['it',
#   's',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   'about',
#   'new',
#   'innovations'],
#  ['s',
#   'about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'new',
#   'innovations'],
#  ['about',
#   'discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'innovations'],
#  ['discovery',
#   'it',
#   's',
#   'about',
#   'new',
#   'products',
#   'it',
#   's',
#   'about',
#   'new'],
#  ['s', 'about', 'changing', 'our', 'frontiers'],
#  ['it', 'about', 'changing', 'our', 'frontiers'],
#  ['it', 's', 'changing', 'our', 'frontiers'],
#  ['it', 's', 'about', 'our', 'frontiers'],
#  ['it', 's', 'about', 'changing', 'frontiers'],
#  ['it', 's', 'about', 'changing', 'our'],
#  ['heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie'],
#  ['our',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso'],
#  ['our',
#   'heroes',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil'],
#  ['our',
#   'heroes',
#   'are',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['our',
#   'heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['heroes',
#   'are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['are',
#   'people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'sir',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['people',
#   'who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'edmund',
#   'hillary',
#   'etc'],
#  ['who',
#   'have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'hillary',
#   'etc'],
#  ['have',
#   'done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'etc'],
#  ['done',
#   'exploration',
#   'madame',
#   'curie',
#   'picasso',
#   'neil',
#   'armstrong',
#   'sir',
#   'edmund',
#   'hillary'],
#  ['come', 'from', 'norway', 'all', 'our', 'heroes', 'are', 'explorers', 'and'],
#  ['i',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they'],
#  ['i',
#   'come',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve'],
#  ['i',
#   'come',
#   'from',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'and',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'they',
#   'deserve',
#   'to',
#   'be'],
#  ['i',
#   'come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'deserve',
#   'to',
#   'be'],
#  ['come',
#   'from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'to',
#   'be'],
#  ['from',
#   'norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'be'],
#  ['norway',
#   'all',
#   'our',
#   'heroes',
#   'are',
#   'explorers',
#   'and',
#   'they',
#   'deserve',
#   'to'],
#  ['all', 'know', 'that', 'exploration', 'is', 'risky'],
#  ['we', 'know', 'that', 'exploration', 'is', 'risky'],
#  ['we', 'all', 'that', 'exploration', 'is', 'risky'],
#  ['we', 'all', 'know', 'exploration', 'is', 'risky'],
#  ['we', 'all', 'know', 'that', 'is', 'risky'],
#  ['we', 'all', 'know', 'that', 'exploration', 'risky'],
#  ['we', 'all', 'know', 'that', 'exploration', 'is'],
#  ['don', 't', 'know', 'the', 'answers', 'we', 'don', 't', 'know'],
#  ['we', 't', 'know', 'the', 'answers', 'we', 'don', 't', 'know', 'if'],
#  ['we', 'don', 'know', 'the', 'answers', 'we', 'don', 't', 'know', 'if', 'we'],
#  ['we',
#   'don',
#   't',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'we',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know'],
#  ['don',
#   't',
#   'know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that'],
#  ['t',
#   'know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the'],
#  ['know',
#   'the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks'],
#  ['the',
#   'answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'are'],
#  ['answers',
#   'we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['we',
#   'don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['don',
#   't',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['t',
#   'know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['know',
#   'if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'that',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['if',
#   'we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'the',
#   'risks',
#   'are',
#   'high'],
#  ['we',
#   're',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'risks',
#   'are',
#   'high'],
#  ['re',
#   'going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'are',
#   'high'],
#  ['going',
#   'to',
#   'find',
#   'them',
#   'and',
#   'we',
#   'know',
#   'that',
#   'the',
#   'risks',
#   'high'],
#  ['to', 'find', 'them', 'and', 'we', 'know', 'that', 'the', 'risks', 'are'],
#  ['is', 'the', 'opposite'],
#  ['exploitation', 'the', 'opposite'],
#  ['exploitation', 'is', 'opposite'],
#  ['exploitation', 'is', 'the'],
#  ['is', 'taking', 'the', 'knowledge', 'we', 'have', 'and', 'making', 'good'],
#  ['exploitation',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'we',
#   'have',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'have',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'and',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'making',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'good',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'making',
#   'better'],
#  ['exploitation',
#   'is',
#   'taking',
#   'the',
#   'knowledge',
#   'we',
#   'have',
#   'and',
#   'making',
#   'good'],
#  ['is', 'about', 'making', 'our', 'trains', 'run', 'on', 'time'],
#  ['exploitation', 'about', 'making', 'our', 'trains', 'run', 'on', 'time'],
#  ['exploitation', 'is', 'making', 'our', 'trains', 'run', 'on', 'time'],
#  ['exploitation', 'is', 'about', 'our', 'trains', 'run', 'on', 'time'],
#  ['exploitation', 'is', 'about', 'making', 'trains', 'run', 'on', 'time'],
#  ['exploitation', 'is', 'about', 'making', 'our', 'run', 'on', 'time'],
#  ['exploitation', 'is', 'about', 'making', 'our', 'trains', 'on', 'time'],
#  ['exploitation', 'is', 'about', 'making', 'our', 'trains', 'run', 'time'],
#  ['exploitation', 'is', 'about', 'making', 'our', 'trains', 'run', 'on'],
#  ['s', 'about', 'making', 'good', 'products', 'faster', 'and', 'cheaper'],
#  ['it', 'about', 'making', 'good', 'products', 'faster', 'and', 'cheaper'],
#  ['it', 's', 'making', 'good', 'products', 'faster', 'and', 'cheaper'],
#  ['it', 's', 'about', 'good', 'products', 'faster', 'and', 'cheaper'],
#  ['it', 's', 'about', 'making', 'products', 'faster', 'and', 'cheaper'],
#  ['it', 's', 'about', 'making', 'good', 'faster', 'and', 'cheaper'],
#  ['it', 's', 'about', 'making', 'good', 'products', 'and', 'cheaper'],
#  ['it', 's', 'about', 'making', 'good', 'products', 'faster', 'cheaper'],
#  ['it', 's', 'about', 'making', 'good', 'products', 'faster', 'and'],
#  ['is', 'not', 'risky', 'in', 'the', 'short', 'term'],
#  ['exploitation', 'not', 'risky', 'in', 'the', 'short', 'term'],
#  ['exploitation', 'is', 'risky', 'in', 'the', 'short', 'term'],
#  ['exploitation', 'is', 'not', 'in', 'the', 'short', 'term'],
#  ['exploitation', 'is', 'not', 'risky', 'the', 'short', 'term'],
#  ['exploitation', 'is', 'not', 'risky', 'in', 'short', 'term'],
#  ['exploitation', 'is', 'not', 'risky', 'in', 'the', 'term'],
#  ['exploitation', 'is', 'not', 'risky', 'in', 'the', 'short'],
#  ['if', 'we', 'only', 'exploit', 'it', 's', 'very', 'risky', 'in'],
#  ['but', 'we', 'only', 'exploit', 'it', 's', 'very', 'risky', 'in', 'the'],
#  ['but',
#   'if',
#   'only',
#   'exploit',
#   'it',
#   's',
#   'very',
#   'risky',
#   'in',
#   'the',
#   'long'],
#  ['but',
#   'if',
#   'we',
#   'exploit',
#   'it',
#   's',
#   'very',
#   'risky',
#   'in',
#   'the',
#   'long',
#   'term'],
#  ['but',
#   'if',
#   'we',
#   'only',
#   'it',
#   's',
#   'very',
#   'risky',
#   'in',
#   'the',
#   'long',
#   'term'],
#  ['but',
#   'if',
#   'we',
# ...
#   'literally',
#   'held',
#   'the',
#   'future',
#   'in',
#   'their',
#   'hands',
#   'but',
#   'couldn',
#   't',
#   'see',
#   'it'],
#  ['they',
#   'literally',
#   'held',
#   'the',
#   'future',
#   'in',
#   'their',
#   'hands',
#   'but',
#   'they',
#   't',
#   'see',
#   'it'],
#  ['literally',
#   'held',
#   'the',
#   'future',
#   'in',
#   'their',
#   'hands',
#   'but',
#   'they',
#   'couldn',
#   'see',
#   'it'],
#  ['held',
#   'the',
#   'future',
#   'in',
#   'their',
#   'hands',
#   'but',
#   'they',
#   'couldn',
#   't',
#   'it'],
#  ['the',
#   'future',
#   'in',
#   'their',
#   'hands',
#   'but',
#   'they',
#   'couldn',
#   't',
#   'see'],
#  ['were', 'simply', 'so', 'good', 'at', 'making', 'what', 'they', 'loved'],
#  ['they',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing'],
#  ['they',
#   'were',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that'],
#  ['they',
#   'were',
#   'simply',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['they',
#   'were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'that',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['were',
#   'simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'they',
#   'wouldn',
#   't',
#   'change'],
#  ['simply',
#   'so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'wouldn',
#   't',
#   'change'],
#  ['so',
#   'good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   't',
#   'change'],
#  ['good',
#   'at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   'change'],
#  ['at',
#   'making',
#   'what',
#   'they',
#   'loved',
#   'doing',
#   'that',
#   'they',
#   'wouldn',
#   't'],
#  ['are', 'like', 'that', 'too'],
#  ['we', 'like', 'that', 'too'],
#  ['we', 'are', 'that', 'too'],
#  ['we', 'are', 'like', 'too'],
#  ['we', 'are', 'like', 'that'],
#  ['we', 'know', 'something', 'well', 'it', 's', 'difficult', 'to', 'change'],
#  ['when', 'know', 'something', 'well', 'it', 's', 'difficult', 'to', 'change'],
#  ['when', 'we', 'something', 'well', 'it', 's', 'difficult', 'to', 'change'],
#  ['when', 'we', 'know', 'well', 'it', 's', 'difficult', 'to', 'change'],
#  ['when', 'we', 'know', 'something', 'it', 's', 'difficult', 'to', 'change'],
#  ['when', 'we', 'know', 'something', 'well', 's', 'difficult', 'to', 'change'],
#  ['when',
#   'we',
#   'know',
#   'something',
#   'well',
#   'it',
#   'difficult',
#   'to',
#   'change'],
#  ['when', 'we', 'know', 'something', 'well', 'it', 's', 'to', 'change'],
#  ['when', 'we', 'know', 'something', 'well', 'it', 's', 'difficult', 'change'],
#  ['when', 'we', 'know', 'something', 'well', 'it', 's', 'difficult', 'to'],
#  ['gates', 'has', 'said', 'success', 'is', 'a', 'lousy', 'teacher'],
#  ['bill', 'has', 'said', 'success', 'is', 'a', 'lousy', 'teacher'],
#  ['bill', 'gates', 'said', 'success', 'is', 'a', 'lousy', 'teacher'],
#  ['bill', 'gates', 'has', 'success', 'is', 'a', 'lousy', 'teacher'],
#  ['bill', 'gates', 'has', 'said', 'is', 'a', 'lousy', 'teacher'],
#  ['bill', 'gates', 'has', 'said', 'success', 'a', 'lousy', 'teacher'],
#  ['bill', 'gates', 'has', 'said', 'success', 'is', 'lousy', 'teacher'],
#  ['bill', 'gates', 'has', 'said', 'success', 'is', 'a', 'teacher'],
#  ['bill', 'gates', 'has', 'said', 'success', 'is', 'a', 'lousy'],
#  ['seduces', 'us', 'into', 'thinking', 'we', 'cannot', 'fail'],
#  ['it', 'us', 'into', 'thinking', 'we', 'cannot', 'fail'],
#  ['it', 'seduces', 'into', 'thinking', 'we', 'cannot', 'fail'],
#  ['it', 'seduces', 'us', 'thinking', 'we', 'cannot', 'fail'],
#  ['it', 'seduces', 'us', 'into', 'we', 'cannot', 'fail'],
#  ['it', 'seduces', 'us', 'into', 'thinking', 'cannot', 'fail'],
#  ['it', 'seduces', 'us', 'into', 'thinking', 'we', 'fail'],
#  ['it', 'seduces', 'us', 'into', 'thinking', 'we', 'cannot'],
#  ['s', 'the', 'challenge', 'with', 'success'],
#  ['that', 'the', 'challenge', 'with', 'success'],
#  ['that', 's', 'challenge', 'with', 'success'],
#  ['that', 's', 'the', 'with', 'success'],
#  ['that', 's', 'the', 'challenge', 'success'],
#  ['that', 's', 'the', 'challenge', 'with'],
#  ['i', 'think', 'there', 'are', 'some', 'lessons', 'and', 'i', 'think'],
#  ['so',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they'],
#  ['so',
#   'i',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply'],
#  ['so',
#   'i',
#   'think',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'think',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'they',
#   'apply',
#   'to',
#   'us'],
#  ['so',
#   'i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'apply',
#   'to',
#   'us'],
#  ['i',
#   'think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'to',
#   'us'],
#  ['think',
#   'there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'us'],
#  ['there',
#   'are',
#   'some',
#   'lessons',
#   'and',
#   'i',
#   'think',
#   'they',
#   'apply',
#   'to'],
#  ['they', 'apply', 'to', 'our', 'companies'],
#  ['and', 'apply', 'to', 'our', 'companies'],
#  ['and', 'they', 'to', 'our', 'companies'],
#  ['and', 'they', 'apply', 'our', 'companies'],
#  ['and', 'they', 'apply', 'to', 'companies'],
#  ['and', 'they', 'apply', 'to', 'our'],
#  ['first', 'lesson', 'is', 'get', 'ahead', 'of', 'the', 'crisis'],
#  ['the', 'lesson', 'is', 'get', 'ahead', 'of', 'the', 'crisis'],
#  ['the', 'first', 'is', 'get', 'ahead', 'of', 'the', 'crisis'],
#  ['the', 'first', 'lesson', 'get', 'ahead', 'of', 'the', 'crisis'],
#  ['the', 'first', 'lesson', 'is', 'ahead', 'of', 'the', 'crisis'],
#  ['the', 'first', 'lesson', 'is', 'get', 'of', 'the', 'crisis'],
#  ['the', 'first', 'lesson', 'is', 'get', 'ahead', 'the', 'crisis'],
#  ['the', 'first', 'lesson', 'is', 'get', 'ahead', 'of', 'crisis'],
#  ['the', 'first', 'lesson', 'is', 'get', 'ahead', 'of', 'the'],
#  ['any', 'company', 'that', 's', 'able', 'to', 'innovate', 'is', 'actually'],
#  ['and',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able'],
#  ['and',
#   'any',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to'],
#  ['and',
#   'any',
#   'company',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'able',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['and',
#   'any',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['any',
#   'company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['company',
#   'that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['that',
#   's',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'an',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['s',
#   'able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'insurance',
#   'in',
#   'the',
#   'future'],
#  ['able',
#   'to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'in',
#   'the',
#   'future'],
#  ['to',
#   'innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'the',
#   'future'],
#  ['innovate',
#   'is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'future'],
#  ['is',
#   'actually',
#   'able',
#   'to',
#   'also',
#   'buy',
#   'an',
#   'insurance',
#   'in',
#   'the'],
#  ['they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier'],
#  ['netflix',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations'],
#  ['netflix',
#   'they',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of'],
#  ['netflix',
#   'they',
#   'could',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think'],
#  ['netflix',
#   'they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they'],
#  ['they',
#   'could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will'],
#  ['could',
#   'so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always'],
#  ['so',
#   'easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep'],
#  ['easily',
#   'have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing'],
#  ['have',
#   'been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for'],
#  ['been',
#   'content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the'],
#  ['content',
#   'with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next'],
#  ['with',
#   'earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['earlier',
#   'generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['generations',
#   'of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['of',
#   'distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['distribution',
#   'but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'pushing',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['but',
#   'they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'for',
#   'the',
#   'next',
#   'battle'],
#  ['they',
#   'always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'the',
#   'next',
#   'battle'],
#  ['always',
#   'and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'next',
#   'battle'],
#  ['and',
#   'i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'battle'],
#  ['i',
#   'think',
#   'they',
#   'will',
#   'always',
#   'keep',
#   'pushing',
#   'for',
#   'the',
#   'next'],
#  ['see', 'other', 'companies', 'that', 'say', 'i', 'll', 'win', 'the'],
#  ['i', 'other', 'companies', 'that', 'say', 'i', 'll', 'win', 'the', 'next'],
#  ['i',
#   'see',
#   'companies',
#   'that',
#   'say',
#   'i',
#   'll',
#   'win',
#   'the',
#   'next',
#   'innovation'],
#  ['i',
#   'see',
#   'other',
#   'that',
#   'say',
#   'i',
#   'll',
#   'win',
#   'the',
#   'next',
#   'innovation',
#   'cycle'],
#  ['i',
#   'see',
#   'other',
#   'companies',
#   'say',
#   'i',
#   'll',
#   'win',
#   'the',
#   'next',
#   'innovation',
#   'cycle',
#   'whatever'],
#  ['i',
#   'see',
#   'other',
#   'companies',
#   'that',
#   'i',
#   'll',
#   'win',
#   'the',
#   'next',
#   'innovation',
#   'cycle',
#   'whatever',
#   'it'],
#  ['i',
#   'see',
#   'other',
#   'companies',
#   'that',
#   'say',
#   'll',
#   'win',
#   'the',
#   'next',
#   'innovation',
#   'cycle',
#   'whatever',
#   'it',
#   'takes'],
#  ['i',
#   'see',
#   'other',
#   'companies',
#   'that',
#   'say',
#   'i',
#   'win',
#   'the',
#   'next',
#   'innovation',
#   'cycle',
#   'whatever',
#   'it',
#   'takes'],
#  ['i',
#   'see',
#   'other',
#   'companies',
#   'that',
#   'say',
#   'i',
#   'll',
#   'the',
#   'next',
#   'innovation',
#   'cycle',
#   'whatever',
#   'it',
#   'takes'],
#  ...]

# %%
business_context_vecs = [] 
for context in business_contexts[0:100]:
    mean = np.mean([model_ted[word] for word in context if word in model_ted], axis=0)
    if not np.isfinite(mean).any():
        print(mean)
    else:
        business_context_vecs.append(mean)

# %%
jail_context_vecs = [np.mean([model_ted[word] for word in context if word in model_ted], axis=0) 
                    for context in jail_contexts[0:100]]

# %%
from bokeh.palettes import d3

tsne = TSNE(n_components=2, random_state=0)
jail_business_tsne = tsne.fit_transform(jail_context_vecs + business_context_vecs)


p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

# set colormap as a list
colormap = d3['Category20'][N]
colors = [colormap[0] for i in range(len(jail_context_vecs))] + [colormap[1] for i in range(len(business_context_vecs))]
# names = ['jail' for i in range(len(jail_context_vecs))] + ['business' for i in range(len(business_context_vecs))]
names = jail_contexts[0:100] + business_contexts[0:100]


source = ColumnDataSource(data=dict(x1=jail_business_tsne[:,0],
                                    x2=jail_business_tsne[:,1],
                                    names=names,
                                    colors=colors))

# p.scatter(x="x1", y="x2", size=8, source=source, fill_color=colors, line_color=None)
p.scatter(x="x1", y="x2", size=8, source=source, color='colors')

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="040d02f6-d578-4fea-85b8-c407766dcf1f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("040d02f6-d578-4fea-85b8-c407766dcf1f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("040d02f6-d578-4fea-85b8-c407766dcf1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '040d02f6-d578-4fea-85b8-c407766dcf1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"96256313-cbe7-4118-beb4-b54f682ed063":{"roots":{"references":[{"attributes":{"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"}},"id":"a7014a52-ecb0-40bb-8c29-7d24bdd4d2f9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"}},"id":"b1752039-dd6e-43de-8173-ec579062bf0d","type":"SaveTool"},{"attributes":{"formatter":{"id":"8fdf9fc7-09b9-46c9-83b9-e62ba9e99759","type":"BasicTickFormatter"},"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"},"ticker":{"id":"d35cc385-b806-4984-8c01-808780b8b192","type":"BasicTicker"}},"id":"09fa2fd4-a308-4bce-8960-fac899a5f6a7","type":"LinearAxis"},{"attributes":{"fill_color":{"field":"colors"},"line_color":{"field":"colors"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"553de422-01de-454d-9cad-6cc6c4981bac","type":"Circle"},{"attributes":{},"id":"d35cc385-b806-4984-8c01-808780b8b192","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"22b1052d-9562-4a12-84f8-c0a55f0fa30b","type":"Circle"},{"attributes":{"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"},"ticker":{"id":"d35cc385-b806-4984-8c01-808780b8b192","type":"BasicTicker"}},"id":"abeb6eb4-7824-4953-b0bb-593fc1e2b8af","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ceb2b505-a8d8-488e-b3df-ff8675f8fc75","type":"PanTool"},{"id":"a7014a52-ecb0-40bb-8c29-7d24bdd4d2f9","type":"WheelZoomTool"},{"id":"d602c5e8-6edd-4e60-bb71-28c82c7407c4","type":"ResetTool"},{"id":"b1752039-dd6e-43de-8173-ec579062bf0d","type":"SaveTool"}]},"id":"b64cecac-17b5-4ab3-80f9-1dc6ea5543b2","type":"Toolbar"},{"attributes":{"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"}},"id":"ceb2b505-a8d8-488e-b3df-ff8675f8fc75","type":"PanTool"},{"attributes":{"formatter":{"id":"e972ed84-c425-4d21-9db1-3e8d95e5b0d2","type":"BasicTickFormatter"},"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"},"ticker":{"id":"a84965b0-e4ac-4d65-9d7a-0dbc1941ff33","type":"BasicTicker"}},"id":"60d42a82-ae60-4dea-b2e1-09df29a88ece","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"ae80326c-466a-4a71-8a9c-882de7376773","subtype":"Figure","type":"Plot"},"ticker":{"id":"a84965b0-e4ac-4d65-9d7a-0dbc1941ff33","type":"BasicTicker"}},"id":"6dfc8a54-62da-4629-94cb-c2b779dedbf8","type":"Grid"},{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words"},"id":"4a2d4159-d83f-4c2b-a9a1-187722498d08","type":"Title"},{"attributes":{"callback":null},"id":"d2f9726e-9863-493b-b02b-e3c5d314b115","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x1","x2","names","colors"],"data":{"colors":["#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77b4","#1f77 ...
